-- %% [markdown]
-- # [dbo].[__EFMigrationsHistory]

-- %%
USE [DigitalShopDev]
GO

-- %%
/****** Object:  Table [dbo].[__EFMigrationsHistory]    Script Date: 08/10/2024 20:50:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[__EFMigrationsHistory](
	[MigrationId] [nvarchar](150) NOT NULL,
	[ProductVersion] [nvarchar](32) NOT NULL,
 CONSTRAINT [PK___EFMigrationsHistory] PRIMARY KEY CLUSTERED 
(
	[MigrationId] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[BASCiudades]

-- %%
/****** Object:  Table [dbo].[BASCiudades]    Script Date: 08/10/2024 20:50:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BASCiudades](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Ciudad] [nvarchar](50) NOT NULL,
	[Estado] [bit] NOT NULL,
	[IdcPais] [int] NOT NULL,
 CONSTRAINT [PK_BASCiudades] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[BASClasificadores]

-- %%
/****** Object:  Table [dbo].[BASClasificadores]    Script Date: 08/10/2024 20:50:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BASClasificadores](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Descripcion] [nvarchar](150) NOT NULL,
	[Estado] [bit] NOT NULL,
	[IdTipo] [int] NOT NULL,
 CONSTRAINT [PK_BASClasificadores] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[BASDirecciones]

-- %%
/****** Object:  Table [dbo].[BASDirecciones]    Script Date: 08/10/2024 20:50:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BASDirecciones](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[IdcPais] [int] NOT NULL,
	[IdcCiudad] [int] NOT NULL,
	[Telefono] [nvarchar](20) NOT NULL,
	[Direccion] [nvarchar](150) NOT NULL,
	[CodigoPostal] [nvarchar](10) NULL,
	[Coordenadas] [nvarchar](500) NULL,
	[Estado] [bit] NOT NULL,
	[IdRelacion] [nvarchar](max) NOT NULL,
 CONSTRAINT [PK_BASDirecciones] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[BASTipos]

-- %%
/****** Object:  Table [dbo].[BASTipos]    Script Date: 08/10/2024 20:50:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BASTipos](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Descripcion] [nvarchar](150) NOT NULL,
	[Estado] [bit] NOT NULL,
 CONSTRAINT [PK_BASTipos] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[INIConfig]

-- %%
/****** Object:  Table [dbo].[INIConfig]    Script Date: 08/10/2024 20:50:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[INIConfig](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Recurso] [nvarchar](50) NULL,
	[Propiedad] [nvarchar](max) NULL,
	[Valor] [nvarchar](max) NULL,
	[Estado] [bit] NOT NULL,
 CONSTRAINT [PK_INIConfig] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[INIEmail]

-- %%
/****** Object:  Table [dbo].[INIEmail]    Script Date: 08/10/2024 20:50:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[INIEmail](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Para] [nvarchar](50) NOT NULL,
	[Asunto] [nvarchar](max) NOT NULL,
	[Contenido] [nvarchar](max) NOT NULL,
	[Estado] [bit] NOT NULL,
 CONSTRAINT [PK_INIEmail] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NEGClientes]

-- %%
/****** Object:  Table [dbo].[NEGClientes]    Script Date: 08/10/2024 20:50:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NEGClientes](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Documento] [nvarchar](20) NOT NULL,
	[Nombres] [nvarchar](50) NOT NULL,
	[Apellidos] [nvarchar](50) NOT NULL,
	[NombreCompleto] [nvarchar](100) NOT NULL,
	[Email] [nvarchar](50) NOT NULL,
	[IdSucursal] [int] NOT NULL,
	[Estado] [bit] NOT NULL,
	[IdUsuarioRegistro] [int] NULL,
	[FechaRegistro] [datetime2](7) NULL,
	[IdUsuarioModificacion] [int] NULL,
	[FechaModificacion] [datetime2](7) NULL,
 CONSTRAINT [PK_NEGClientes] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NEGEmpresas]

-- %%
/****** Object:  Table [dbo].[NEGEmpresas]    Script Date: 08/10/2024 20:50:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NEGEmpresas](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[NitEmpresa] [nvarchar](15) NOT NULL,
	[NombreEmpresa] [nvarchar](250) NOT NULL,
	[Email] [nvarchar](50) NOT NULL,
	[Leyenda] [nvarchar](250) NULL,
	[UrlLogo] [nvarchar](1000) NULL,
	[NombreContacto] [nvarchar](250) NULL,
	[TelefonoContacto] [nvarchar](15) NULL,
	[IdcCategoria] [int] NOT NULL,
	[Estado] [bit] NOT NULL,
	[Ubicacion] [bit] NOT NULL,
	[Coordenadas] [nvarchar](500) NULL,
	[IdUsuarioRegistro] [int] NULL,
	[FechaRegistro] [datetime2](7) NULL,
	[IdUsuarioModificacion] [int] NULL,
	[FechaModificacion] [datetime2](7) NULL,
 CONSTRAINT [PK_NEGEmpresas] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NEGProductos]

-- %%
/****** Object:  Table [dbo].[NEGProductos]    Script Date: 08/10/2024 20:50:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NEGProductos](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[IdSucursal] [int] NOT NULL,
	[IdcCategoria] [int] NOT NULL,
	[Codigo] [nvarchar](50) NOT NULL,
	[NombreProducto] [nvarchar](100) NOT NULL,
	[Descripcion] [nvarchar](200) NULL,
	[Stock] [int] NOT NULL,
	[IdcMedida] [int] NOT NULL,
	[PrecioCompra] [decimal](18, 2) NOT NULL,
	[PrecioVenta] [decimal](18, 2) NOT NULL,
	[UrlImagen] [nvarchar](max) NULL,
	[Estado] [bit] NOT NULL,
	[IdUsuarioRegistro] [int] NULL,
	[FechaRegistro] [datetime2](7) NULL,
	[IdUsuarioModificacion] [int] NULL,
	[FechaModificacion] [datetime2](7) NULL,
 CONSTRAINT [PK_NEGProductos] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NEGSucursales]

-- %%
/****** Object:  Table [dbo].[NEGSucursales]    Script Date: 08/10/2024 20:50:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NEGSucursales](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[IdcCiudad] [int] NOT NULL,
	[NombreSucursal] [nvarchar](250) NOT NULL,
	[Estado] [bit] NOT NULL,
	[IdEmpresa] [int] NOT NULL,
	[IdUsuarioRegistro] [int] NULL,
	[FechaRegistro] [datetime2](7) NULL,
	[IdUsuarioModificacion] [int] NULL,
	[FechaModificacion] [datetime2](7) NULL,
 CONSTRAINT [PK_NEGSucursales] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SEGUsuarios]

-- %%
/****** Object:  Table [dbo].[SEGUsuarios]    Script Date: 08/10/2024 20:50:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SEGUsuarios](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[NombreCompleto] [nvarchar](100) NOT NULL,
	[Email] [nvarchar](50) NOT NULL,
	[Clave] [nvarchar](10) NOT NULL,
	[IdcRol] [int] NOT NULL,
	[IdEmpresa] [int] NOT NULL,
	[IdSucursal] [int] NOT NULL,
	[Estado] [bit] NOT NULL,
	[FechaRegistro] [datetime2](7) NULL,
	[FechaModificacion] [datetime2](7) NULL,
 CONSTRAINT [PK_SEGUsuarios] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TRXDetalleVentas]

-- %%
/****** Object:  Table [dbo].[TRXDetalleVentas]    Script Date: 08/10/2024 20:50:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TRXDetalleVentas](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CodigoProducto] [nvarchar](50) NOT NULL,
	[Nombre] [nvarchar](100) NOT NULL,
	[Descripcion] [nvarchar](200) NOT NULL,
	[IdMedida] [int] NOT NULL,
	[PrecioUnitario] [decimal](18, 2) NOT NULL,
	[Cantidad] [int] NOT NULL,
	[SubTotal] [decimal](18, 2) NOT NULL,
	[IdVenta] [int] NOT NULL,
 CONSTRAINT [PK_TRXDetalleVentas] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TRXVentas]

-- %%
/****** Object:  Table [dbo].[TRXVentas]    Script Date: 08/10/2024 20:50:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TRXVentas](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[IdCliente] [int] NOT NULL,
	[Coordenadas] [nvarchar](250) NOT NULL,
	[IdcFormaEntrega] [int] NOT NULL,
	[IdcFormaPago] [int] NOT NULL,
	[IdcEstadoPago] [int] NOT NULL,
	[IdcEstadoVenta] [int] NOT NULL,
	[IdSucursal] [int] NOT NULL,
	[IdUsuarioRegistro] [int] NULL,
	[FechaRegistro] [datetime2](7) NULL,
	[IdUsuarioModificacion] [int] NULL,
	[FechaModificacion] [datetime2](7) NULL,
 CONSTRAINT [PK_TRXVentas] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TRXVentasCredito]

-- %%
/****** Object:  Table [dbo].[TRXVentasCredito]    Script Date: 08/10/2024 20:50:43 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TRXVentasCredito](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[IdcEstadoCredito] [int] NOT NULL,
	[DeudaInicial] [decimal](18, 2) NOT NULL,
	[MontoPagado] [decimal](18, 2) NOT NULL,
	[DeudaActual] [decimal](18, 2) NOT NULL,
	[Comentarios] [nvarchar](1050) NULL,
	[IdVenta] [int] NOT NULL,
	[IdUsuarioRegistro] [int] NULL,
	[FechaRegistro] [datetime2](7) NULL,
	[IdUsuarioModificacion] [int] NULL,
	[FechaModificacion] [datetime2](7) NULL,
 CONSTRAINT [PK_TRXVentasCredito] PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO
